# %%
from msdas import *
# %pylab inline
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Populating the interactive namespace from numpy and matplotlib

# %%
curated_pkn = "../../../share/data/PKN-yeastScaffold.sif"

# %%
y = yeast.YEAST2MIDAS(get_yeast_small_data(), get_yeast_raw_data())
# Out:
# /home/cokelaer/Work/virtualenv/svn-sysbiomed/trunk/cinapps/msdas/src/msdas/readers.py:640: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self.df['Sequence'] = list(self.df['Sequence_Phospho'].values)
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/core/indexing.py:344: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self.obj[item] = s
# WARNING:root:Rebuilding identifier in the dataframe
# WARNING:root:Identifiers are not unique. Have you called merge_peptides() ?
# INFO:root:Renaming psites with ^ character
# INFO:root:Replacing zeros with NAs
# INFO:root:-- Removing 0 rows with ambigous protein names:
# INFO:root:--------------------------------------------------
# WARNING:root:Rebuilding identifier in the dataframe
# INFO:root:Filling Nas with zeros if any
# INFO:root:data is in `df` attribute and full raw data with replicates in `replicates` attribute

# %%
y.df.Psite[0:5]
# Out:
# 0         S126+S127
# 1              S142
# 2              S272
# 3         S272^S275
# 4    S272^T277^S279
# Name: Psite, dtype: object

# %%
y['GPA1']
# Out:
#    Protein                 Sequence Psite                  Sequence_Phospho  \
# 14    GPA1  SDTDRDAETVTQNEDADRNNSSR  S199  SDTDRDAETVTQNEDADRNNS(Phospho)SR
#
#        a0_t0     a0_t1    a0_t5    a0_t10    a0_t20    a0_t45     a1_t0  \
# 14  0.000111  0.000101  0.00018  0.000183  0.000127  0.000106  0.000126
#
#        a1_t1     a1_t5    a1_t10   a1_t20    a1_t45     a5_t0     a5_t1  \
# 14  0.000146  0.000196  0.000165  0.00014  0.000113  0.000146  0.000059
#
#       a5_t5    a5_t10
# 14  0.00009  0.000099 ...
#
# [1 rows x 43 columns]

# %%
y.replicates['GPA1']
# Out:
#      Protein                                           Sequence  \
# 4708    GPA1  MERGED_1Phosphos_3locations_SDTDRDAETVTQNEDADR...
#
#                Psite                                   Sequence_Phospho  \
# 4708  T189+S199+S200  MERGED_1Phosphos_3locations_SDTDRDAETVTQNEDADR...
#
#          a0_t0   a0_t0.1   a0_t0.2     a0_t1   a0_t1.1   a0_t1.2     a0_t5  \
# 4708  0.000107  0.000103  0.000124  0.000095  0.000102  0.000106  0.000193
#
#        a0_t5.1   a0_t5.2    a0_t10  a0_t10.1  a0_t10.2    a0_t20  a0_t20.1  \
# 4708  0.000161  0.000187  0.000152  0.000204  0.000193  0.000121  0.000121
#
#       a0_t20.2    a0_t45
# 4708  0.000138  0.000106 ...
#
# [1 rows x 115 columns]

# %%
y.plot_timeseries("GPA1_S199")
y.replicates.plot_timeseries("GPA1_T189+S199+S200", color="green")
ax = gca()
ax.legend(["small", "raw"])

# %%
errors = y.get_errors()
errors.ix["GPA1_S199"]
# Out:
# INFO:root:fillinf NA with 0.5
# a0_t0      0.5
# a0_t1      0.5
# a0_t5      0.5
# a0_t10     0.5
# a0_t20     0.5
# a0_t45     0.5
# a1_t0      0.5
# a1_t1      0.5
# a1_t5      0.5
# a1_t10     0.5
# a1_t20     0.5
# a1_t45     0.5
# a5_t0      0.5
# a5_t1      0.5
# a5_t5      0.5
# a5_t10     0.5
# a5_t20     0.5
# a5_t45     0.5
# a10_t0     0.5
# a10_t1     0.5
# a10_t5     0.5
# a10_t10    0.5
# a10_t20    0.5
# a10_t45    0.5
# a20_t0     0.5
# a20_t1     0.5
# a20_t5     0.5
# a20_t10    0.5
# a20_t20    0.5
# a20_t45    0.5
# a45_t0     0.5
# a45_t1     0.5
# a45_t5     0.5
# a45_t10    0.5
# a45_t20    0.5
# a45_t45    0.5
# Name: GPA1_S199, dtype: float64

# %% [markdown]
# Here are errors at set to 0.5 (default if NA). This means that errors were NAs or could not be found.
# The reason for not being found is that labels in the merged raw data are different. We must call a function called cleanup_june

# %%
y.cleanup_june()
errors = y.get_errors()
errors.ix["GPA1_T189+S199+S200"]
# Out:
# INFO:root:Renaming psites with ^ character
# INFO:root:Replacing zeros with NAs
# INFO:root:-- 2 rows have ambiguous psites and are removed
# INFO:root:save data in attribute _ambiguous_psites_df
# INFO:root:--------------------------------------------------
# INFO:root:-- Removing 0 rows with ambigous protein names:
# INFO:root:--------------------------------------------------
# WARNING:root:Rebuilding identifier in the dataframe
# WARNING:root:Identifiers are not unique. Have you called merge_peptides() ?
# INFO:root:Filling Nas with zeros if any
# INFO:root:fillinf NA with 0.5
# 57
# a0_t0      0.099538
# a0_t1      0.054123
# a0_t5      0.094096
# a0_t10     0.149148
# a0_t20     0.075287
# a0_t45     0.500000
# a1_t0      0.180624
# a1_t1      0.008147
# a1_t5      0.170706
# a1_t10     0.016397
# a1_t20     0.033809
# a1_t45     0.500000
# a5_t0      0.500000
# a5_t1      0.500000
# a5_t5      0.500000
# a5_t10     0.045989
# a5_t20     0.500000
# a5_t45     0.675384
# a10_t0     0.091016
# a10_t1     0.151073
# a10_t5     0.144490
# a10_t10    0.064962
# a10_t20    0.144356
# a10_t45    0.059137
# a20_t0     0.321291
# a20_t1     0.198459
# a20_t5     0.178139
# a20_t10    0.500000
# a20_t20    0.500000
# a20_t45    0.500000
# a45_t0     0.066963
# a45_t1     0.500000
# a45_t5     0.500000
# a45_t10    0.077377
# a45_t20    0.096006
# a45_t45    0.500000
# Name: GPA1_T189+S199+S200, dtype: float64

# %%
y.plot_timeseries_midas('GPA1_T189+S199+S200')
# Out:
# INFO:root:fillinf NA with 0.5

# %%
curated_pkn
# Out:
# '../../../share/data/PKN-yeastScaffold.sif'

# %%
preference = -1 # meas no clustering 
c, xm, xme = y.export_pkn_and_midas_june(curated_pkn, tag="test")
# Out:
# reanming PTP2 -> PTP2_Y257-S258
# reanming HOT1 -> HOT1_S153
# reanming STE11 -> STE11_S323-S326-S326
# reanming STE12 -> STE12_S400
# reanming SLN1 -> SLN1_S833
# reanming STE50 -> STE50_S202
# reanming GPA1 -> GPA1_T189-S199-S200
# reanming STE2 -> STE2_S331
# reanming FAR1 -> FAR1_S114
# reanming SSK2 -> SSK2_S53-S54~S57
# building
# 2
# 3
# 4
# building
# 2
# 3
# 4

# %%
c.graph['dpi'] = 200; 
c.plot()
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']
# Out:
# INFO:root:dot -Tpng /tmp/tmpUfK3Ry.dot -o /tmp/tmpG7K3Q_.png

# %%
matplotlib.rcParams['savefig.dpi'] = .5 * matplotlib.rcParams['savefig.dpi']
xm.plot()

# %%
xm.scale_max_by_experiments()
xm.plot()

# %%
xme.plot()

# %%
c.export2sif("PKN-Yeast-test.sif")
xm.save2midas("MD-Yeast_test_max_byexp.csv")
xme.save2midas("MD-Yeast_test_errors.csv")

# %%
xm.reset()  # let us get back the original data to scale with other methods

# %%
xm.scale_max_across_experiments()
xm.save2midas("MD-Yeast_test_max_across.csv")

# %%
xm.reset()
xm.scale_min_max_by_experiments()
xm.save2midas("MD-Yeast_test_minmax_byexp.csv")

xm.reset()
xm.scale_min_max_by_experiments(1)  # will be renamed 
xm.save2midas("MD-Yeast_test_minmax_across.csv")
