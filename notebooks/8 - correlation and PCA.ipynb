# %%
from msdas import *
# %pylab inline
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Populating the interactive namespace from numpy and matplotlib

# %%
Y = replicates.ReplicatesYeast(get_yeast_raw_data(), verbose=True, cleanup=True)
# Out:
# INFO:root:Reading /home/cokelaer/Work/svn-sysbiomed/trunk/cinapps/msdas/share/data/Yeast_all_raw.csv
# INFO:root:Renaming psites with ^ character
# INFO:root:Replacing zeros with NAs
# INFO:root:-- 200 rows have ambiguous psites and are removed
# INFO:root:save data in attribute _ambiguous_psites_df
# INFO:root:--------------------------------------------------
# INFO:root:-- Removing 125 rows with ambigous protein names:
# INFO:root:--------------------------------------------------
# WARNING:root:Rebuilding identifier in the dataframe
# WARNING:root:Identifiers are not unique. Have you called merge_peptides() ?

# %%
Ymerged = Y.copy()

# %%
Ymerged.drop_oxidation()
# Out:
# /home/cokelaer/Work/svn-sysbiomed/trunk/cinapps/msdas/src/msdas/readers.py:646: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self.df['Sequence'] = list(self.df['Sequence_Phospho'])
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/core/indexing.py:344: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self.obj[item] = s

# %%
Ymerged.drop_na_exceeds_minnonzero()
Ymerged.merge_peptides()

# %%
imshow(Y.df.corr())
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x79bb830>

# %%
imshow(Ymerged.df.corr())
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x97d83b0>
